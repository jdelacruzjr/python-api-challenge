# %% [markdown]
# ## VacationPy
#
# ### Observable Trends and Insights----
#
# #### Using a Geoapify API, heat maps I can create an exploratory-interactive geospatial visualization to discover value buried within datasets too large to assess by quick visual inspection alone.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import hvplot.pandas
import pandas as pd
import numpy as np
import requests
import geoviews as gv
import os
import numpy as np
import json
import warnings
#warnings.filterwarnings("ignore")

# Import the API key
from api_keys import geoapify_key

# %% [markdown]
# # Create a map that displays a point for every city in the city_data_df DataFrame. The size of the point should be the level of humidity in each city.

# %%
# Load the csv exported in Part I to a DataFrame

city_data_df = pd.read_csv("output_data/cities.csv")

city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       gushikawa  26.3544  127.8686     16.57        77         100
# 1        1  port macquarie -31.4333  152.9167     19.94        48           0
# 2        2        la palma  33.8464 -118.0467     22.50        37          40
# 3        3         ushuaia -54.8000  -68.3000     10.81        87          75
# 4        4      butaritari   3.0707  172.7902     27.38        76           4
#
#    Wind Speed Country        Date
# 0        0.00      JP  1675452254
# 1        6.16      AU  1675452255
# 2        2.06      US  1675452256
# 3       12.86      AR  1675452111
# 4        8.96      KI  1675452259

# %% [markdown]
# # Humidity Heatmap
#
# ## Use the Lat and Lng as locations and Humidity as the weight.
# ## Add Heatmap layer to map.

# %%
# Convert Humidity to float and store
humidity = city_data_df["Humidity"].astype(float)

# %%
# Store 'Latitude' and 'Longitude' into locations. 
locations = city_data_df[["Lat", "Lng"]].astype(float)

# %%
city_data_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0          0          gushikawa  26.3544  127.8686     16.57        77
# 1          1     port macquarie -31.4333  152.9167     19.94        48
# 2          2           la palma  33.8464 -118.0467     22.50        37
# 3          3            ushuaia -54.8000  -68.3000     10.81        87
# 4          4         butaritari   3.0707  172.7902     27.38        76
# ..       ...                ...      ...       ...       ...       ...
# 587      587  guadalupe y calvo  26.1000 -106.9667     17.39        20
# 588      588            kon tum  14.3500  108.0000     17.34        97
# 589      589          sandpoint  48.2766 -116.5533      2.59        77
# 590      590          batsfjord  70.6345   29.7185     -1.04        93
# 591      591      moose factory  51.2585  -80.6094    -29.00        57
#
#      Cloudiness  Wind Speed Country        Date
# 0           100        0.00      JP  1675452254
# 1             0        6.16      AU  1675452255
# 2            40        2.06      US  1675452256
# 3            75       12.86      AR  1675452111
# 4             4        8.96      KI  1675452259
# ..          ...         ...     ...         ...
# 587          11        1.80      MX  1675452869
# 588          27        1.26      VN  1675452869
# 589          40        2.06      US  1675452634
# 590          75        6.17      NO  1675452872
# 591         100        6.69      CA  1675452872
#
# [592 rows x 10 columns]

# %%
# Configure the map
locations_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1.5,
    color = "City",
    hover_cols = ["City", "Lat", "Lng", "Humidity"]
)

# Display the map plot
locations_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# # Narrow down the city_data_df DataFrame to find your ideal weather conditions

# %%
# Narrow down the DataFrame to find your ideal weather condition.
# Drop any rows that don't contain all three conditions. To be sure the weather is ideal.

# A max temperature lower than 27 degrees but higher than 21.
temp_df = city_data_df.loc[(city_data_df["Max Temp"] < 27) &
                    (city_data_df["Max Temp"] > 21), :]
# Wind speed less than 4.5 m/s.
wind_df = temp_df.loc[(temp_df["Wind Speed"] < 4.5), :]

# Zero cloudiness.
cloudiness_df = wind_df.loc[(wind_df["Cloudiness"] == 0), :]

# Drop any rows with null values
dropped_nulls_df = temp_df.dropna()

dropped_nulls_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 2          2        la palma  33.8464 -118.0467     22.50        37
# 9          9           kapaa  22.0752 -159.3190     22.99        94
# 12        12  port elizabeth -33.9180   25.5701     23.94        89
# 25        25       carnarvon -24.8667  113.6333     26.08        77
# 28        28           vaini -21.2000 -175.2000     24.09        94
# ..       ...             ...      ...       ...       ...       ...
# 569      569      carutapera  -1.1950  -46.0200     26.99        79
# 575      575    nueva guinea  11.6876  -84.4562     26.79        67
# 581      581          omboue  -1.5746    9.2618     26.79        86
# 582      582          tandil -37.3217  -59.1332     25.38        33
# 583      583         ambanja -13.6833   48.4500     24.30        92
#
#      Cloudiness  Wind Speed Country        Date
# 2            40        2.06      US  1675452256
# 9           100       10.80      US  1675452264
# 12           75        4.63      ZA  1675452266
# 25           11        3.09      AU  1675452275
# 28           75        4.63      TO  1675452278
# ..          ...         ...     ...         ...
# 569          17        4.10      BR  1675452786
# 575          43        6.06      NI  1675452793
# 581          18        2.97      GA  1675452764
# 582          31        5.30      AR  1675452601
# 583          86        0.94      MG  1675452866
#
# [135 rows x 10 columns]

# %% [markdown]
# # Create new DataFrame called hotel_df

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
cols_left = ["City", "Country", "Lat", "Lng", "Humidity"]
hotel_df = dropped_nulls_df[cols_left].copy()

# Add empty column, "Hotel Name" to dataframe to store hotels found when using Geoapify
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 2          la palma      US  33.8464 -118.0467        37
# 9             kapaa      US  22.0752 -159.3190        94
# 12   port elizabeth      ZA -33.9180   25.5701        89
# 25        carnarvon      AU -24.8667  113.6333        77
# 28            vaini      TO -21.2000 -175.2000        94
# ..              ...     ...      ...       ...       ...        ...
# 569      carutapera      BR  -1.1950  -46.0200        79
# 575    nueva guinea      NI  11.6876  -84.4562        67
# 581          omboue      GA  -1.5746    9.2618        86
# 582          tandil      AR -37.3217  -59.1332        33
# 583         ambanja      MG -13.6833   48.4500        92
#
# [135 rows x 6 columns]

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories" : "accommodation.hotel",
          "apiKey" : geoapify_key}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# la palma - nearest hotel: No hotel found
# kapaa - nearest hotel: No hotel found
# port elizabeth - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# vaini - nearest hotel: No hotel found
# port alfred - nearest hotel: No hotel found
# bengkulu - nearest hotel: No hotel found
# phan thiet - nearest hotel: No hotel found
# maldonado - nearest hotel: No hotel found
# georgetown - nearest hotel: No hotel found
# mar del plata - nearest hotel: No hotel found
# shwebo - nearest hotel: No hotel found
# atuona - nearest hotel: No hotel found
# rikitea - nearest hotel: No hotel found
# ancud - nearest hotel: No hotel found
# san vicente - nearest hotel: No hotel found
# cidreira - nearest hotel: No hotel found
# banda aceh - nearest hotel: No hotel found
# salalah - nearest hotel: No hotel found
# kahului - nearest hotel: No hotel found
# alofi - nearest hotel: No hotel found
# byron bay - nearest hotel: No hotel found
# namatanai - nearest hotel: No hotel found
# satipo - nearest hotel: No hotel found
# hilo - nearest hotel: No hotel found
# bambous virieux - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# shakawe - nearest hotel: No hotel found
# poya - nearest hotel: No hotel found
# eirunepe - nearest hotel: No hotel found
# trincomalee - nearest hotel: No hotel found
# ambulu - nearest hotel: No hotel found
# namibe - nearest hotel: No hotel found
# dakar - nearest hotel: No hotel found
# dingle - nearest hotel: No hotel found
# champoton - nearest hotel: No hotel found
# ternate - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# honiara - nearest hotel: No hotel found
# mahebourg - nearest hotel: No hotel found
# hambantota - nearest hotel: No hotel found
# saint-philippe - nearest hotel: No hotel found
# hobyo - nearest hotel: No hotel found
# alta floresta - nearest hotel: No hotel found
# bilma - nearest hotel: No hotel found
# atambua - nearest hotel: No hotel found
# mangrol - nearest hotel: No hotel found
# marang - nearest hotel: No hotel found
# souillac - nearest hotel: No hotel found
# tam ky - nearest hotel: No hotel found
# kulhudhuffushi - nearest hotel: No hotel found
# cobija - nearest hotel: No hotel found
# kieta - nearest hotel: No hotel found
# isabela - nearest hotel: No hotel found
# cap malheureux - nearest hotel: No hotel found
# bowen - nearest hotel: No hotel found
# dhidhdhoo - nearest hotel: No hotel found
# hervey bay - nearest hotel: No hotel found
# cukai - nearest hotel: No hotel found
# matara - nearest hotel: No hotel found
# kerema - nearest hotel: No hotel found
# ixtapa - nearest hotel: No hotel found
# gombong - nearest hotel: No hotel found
# tocopilla - nearest hotel: No hotel found
# daru - nearest hotel: No hotel found
# gigmoto - nearest hotel: No hotel found
# madaoua - nearest hotel: No hotel found
# veraval - nearest hotel: No hotel found
# kupang - nearest hotel: No hotel found
# imbituba - nearest hotel: No hotel found
# meulaboh - nearest hotel: No hotel found
# palmerston - nearest hotel: No hotel found
# makakilo city - nearest hotel: No hotel found
# lorengau - nearest hotel: No hotel found
# batticaloa - nearest hotel: No hotel found
# sur - nearest hotel: No hotel found
# atar - nearest hotel: No hotel found
# danielskuil - nearest hotel: No hotel found
# bandarbeyla - nearest hotel: No hotel found
# banyo - nearest hotel: No hotel found
# san policarpo - nearest hotel: No hotel found
# inhambane - nearest hotel: No hotel found
# xuddur - nearest hotel: No hotel found
# nouadhibou - nearest hotel: No hotel found
# tabou - nearest hotel: No hotel found
# hualmay - nearest hotel: No hotel found
# rio claro - nearest hotel: No hotel found
# cururupu - nearest hotel: No hotel found
# kruisfontein - nearest hotel: No hotel found
# bonthe - nearest hotel: No hotel found
# navirai - nearest hotel: No hotel found
# pulivendla - nearest hotel: No hotel found
# ankazoabo - nearest hotel: No hotel found
# ituverava - nearest hotel: No hotel found
# charters towers - nearest hotel: No hotel found
# trinidad - nearest hotel: No hotel found
# mackay - nearest hotel: No hotel found
# saint-raphael - nearest hotel: No hotel found
# kota belud - nearest hotel: No hotel found
# ouango - nearest hotel: No hotel found
# lahad datu - nearest hotel: No hotel found
# waingapu - nearest hotel: No hotel found
# kununurra - nearest hotel: No hotel found
# porto walter - nearest hotel: No hotel found
# turan - nearest hotel: No hotel found
# kirakira - nearest hotel: No hotel found
# kulim - nearest hotel: No hotel found
# merauke - nearest hotel: No hotel found
# pak phanang - nearest hotel: No hotel found
# liku - nearest hotel: No hotel found
# majene - nearest hotel: No hotel found
# boueni - nearest hotel: No hotel found
# pandan - nearest hotel: No hotel found
# necochea - nearest hotel: No hotel found
# tanout - nearest hotel: No hotel found
# baturaja - nearest hotel: No hotel found
# payo - nearest hotel: No hotel found
# kota bahru - nearest hotel: No hotel found
# arlit - nearest hotel: No hotel found
# dawei - nearest hotel: No hotel found
# bintulu - nearest hotel: No hotel found
# mahibadhoo - nearest hotel: No hotel found
# sao filipe - nearest hotel: No hotel found
# praya - nearest hotel: No hotel found
# diffa - nearest hotel: No hotel found
# huarmey - nearest hotel: No hotel found
# mana - nearest hotel: No hotel found
# aripuana - nearest hotel: No hotel found
# mindelo - nearest hotel: No hotel found
# trat - nearest hotel: No hotel found
# carutapera - nearest hotel: No hotel found
# nueva guinea - nearest hotel: No hotel found
# omboue - nearest hotel: No hotel found
# tandil - nearest hotel: No hotel found
# ambanja - nearest hotel: No hotel found
#                City Country      Lat       Lng  Humidity      Hotel Name
# 2          la palma      US  33.8464 -118.0467        37  No hotel found
# 9             kapaa      US  22.0752 -159.3190        94  No hotel found
# 12   port elizabeth      ZA -33.9180   25.5701        89  No hotel found
# 25        carnarvon      AU -24.8667  113.6333        77  No hotel found
# 28            vaini      TO -21.2000 -175.2000        94  No hotel found
# ..              ...     ...      ...       ...       ...             ...
# 569      carutapera      BR  -1.1950  -46.0200        79  No hotel found
# 575    nueva guinea      NI  11.6876  -84.4562        67  No hotel found
# 581          omboue      GA  -1.5746    9.2618        86  No hotel found
# 582          tandil      AR -37.3217  -59.1332        33  No hotel found
# 583         ambanja      MG -13.6833   48.4500        92  No hotel found
#
# [135 rows x 6 columns]

# %% [markdown]
# # Add hotel name and country as additional information in hover message for each city in the map

# %%
# Configure the map plot
final_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo= True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 1.5,
    size= "Humidity",
    color = "City",
    hover_cols = ["Lng", "Lat", "City", "Humidity", "Hotel Name", "Country"]
)

# Display the map
final_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
